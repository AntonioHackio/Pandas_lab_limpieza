# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Limpieza de Datos
#
# En este laboratorio usaremos el DataFrame de Netflix completo creado en los primeros laboratorios de Pandas.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.
#
# 3. Documenta todas las funciones creadas durante el ejercicio.
#
# 4. Debes incluir después de cada gráfica la interpretación de las mismas en una celda de markdown.

# %%
import pandas as pd
import numpy as np

from pandas import ExcelWriter
import itertools

pd.set_option('display.max_columns', None)

df_union_final = pd.read_csv("datos/df_union_final.csv", index_col = 0)

df_union_final
# Out:
#      show_id     type                          title  \
# 0      s2037    Movie                         #Alive
# 1      s2305    Movie  #AnneFrank - Parallel Stories
# 2      s2482    Movie              #FriendButMarried
# 3      s2325    Movie            #FriendButMarried 2
# 4      s5974    Movie                          #Roxy
# ...      ...      ...                            ...
# 8802   s6178  TV Show                       忍者ハットリくん
# 8803   s4915  TV Show                           海的儿子
# 8804   s7102  TV Show                           마녀사냥
# 8805   s5023    Movie                        반드시 잡는다
# 8806   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 0                          Cho Il
# 1     Sabina Fedeli, Anna Migotto
# 2                   Rako Prijanto
# 3                   Rako Prijanto
# 4                 Michael Kennedy
# ...                           ...
# 8802                          NaN
# 8803                          NaN
# 8804                          NaN
# 8805                Hong-seon Kim
# 8806                Young Jun Lee
#
#                                                    cast      country  \
# 0                              Yoo Ah-in, Park Shin-hye  South Korea
# 1                           Helen Mirren, Gengher Gatti        Italy
# 2     Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...    Indonesia
# 3     Adipati Dolken, Mawar de Jongh, Sari Nila, Von...    Indonesia
# 4     Jake Short, Sarah Fisher, Booboo Stewart, Dann...       Canada
# ...                                                 ...          ...
# 8802                                                NaN        Japan
# 8803  Li Nanxing, Christopher Lee, Jesseca Liu, Appl...          NaN
# 8804  Si-kyung Sung, Se-yoon Yoo, Dong-yup Shin, Ji-...  South Korea
# 8805                                      Baek Yoon-sik  South Korea
# 8806  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...          NaN
#
#               date_added  release_year rating   duration  \
# 0      September 8, 2020          2020  TV-MA        NaN
# 1           July 1, 2020          2019  TV-14        NaN
# 2           May 21, 2020          2018   TV-G        NaN
# 3          June 28, 2020          2020   TV-G    104 min
# 4         April 10, 2019          2018  TV-14        NaN
# ...                  ...           ...    ...        ...
# 8802   December 23, 2018          2012  TV-Y7  2 Seasons
# 8803      April 27, 2018          2016  TV-14        NaN
# 8804   February 19, 2018          2015  TV-MA        NaN
# 8805   February 28, 2018          2017  TV-MA    110 min
# 8806   September 1, 2018          2018  TV-Y7     68 min
#
#                                               listed_in  \
# 0        Horror Movies, International Movies, Thrillers
# 1                   Documentaries, International Movies
# 2         Dramas, International Movies, Romantic Movies
# 3         Dramas, International Movies, Romantic Movies
# 4                             Comedies, Romantic Movies
# ...                                                 ...
# 8802                             Anime Series, Kids' TV
# 8803                  International TV Shows, TV Dramas
# 8804  International TV Shows, Korean TV Shows, Stand...
# 8805            Dramas, International Movies, Thrillers
# 8806                           Children & Family Movies
#
#                                             description Genre Premiere  \
# 0     As a grisly virus rampages a city, a lone man ...   NaN      NaN
# 1     Through her diary, Anne Frank's story is retol...   NaN      NaN
# 2     Pining for his high school crush for years, a ...   NaN      NaN
# 3     As Ayu and Ditto finally transition from best ...   NaN      NaN
# 4     A teenage hacker with a huge nose helps a cool...   NaN      NaN
# ...                                                 ...   ...      ...
# 8802  Hailing from the mountains of Iga, Kanzo Hatto...   NaN      NaN
# 8803  Two brothers start a new life in Singapore, wh...   NaN      NaN
# 8804  Four Korean celebrity men and guest stars of b...   NaN      NaN
# 8805  After people in his town start turning up dead...   NaN      NaN
# 8806  Miniforce, a special task force of elite range...   NaN      NaN
#
#       Runtime  IMDB Score Language
# 0         NaN         NaN      NaN
# 1         NaN         NaN      NaN
# 2         NaN         NaN      NaN
# 3         NaN         NaN      NaN
# 4         NaN         NaN      NaN
# ...       ...         ...      ...
# 8802      NaN         NaN      NaN
# 8803      NaN         NaN      NaN
# 8804      NaN         NaN      NaN
# 8805      NaN         NaN      NaN
# 8806      NaN         NaN      NaN
#
# [8807 rows x 17 columns]

# %% [markdown]
# ## Parte 1: Limpieza y Preparación de Datos

# %% [markdown]
# #### Ejercicio 1: Estandarización y limpieza de columnas
#
# En este ejercicio, debes limpiar y estandarizar algunas columnas clave para hacerlas más manejables y consistentes en tus análisis. Específicamente, trabajarás con las columnas `date_added` y `duration` para convertirlas a un formato uniforme y estructurado.
#
# Instrucciones:
#
# 1. **Convertir la columna `date_added`**: La columna `date_added` contiene fechas en formato de texto. Debes convertirla a un formato `datetime` que pandas pueda entender y manejar fácilmente.
#
# 2. **Limpiar la columna `duration`**: La columna `duration` tiene valores en diferentes formatos como "1 Season", "2 Seasons", "90 min", etc. Tu tarea es extraer el número (ya sea el número de temporadas o la cantidad de minutos) y crear una nueva columna llamada `duration_cleaned` con esos valores estandarizados.
#
#
# **Resultado Esperado:**
# Deberás obtener algo como esto:
#
# | duration   | duration_cleaned |
# |------------|-----------------|
# | 1 Season   | 1               |
# | 90 min     | 90              |
# | 2 Seasons  | 2               |
# | 45 min     | 45              |
# | 3 Seasons  | 3               |

# %%
df_union_final["fecha"] = pd.to_datetime(df_union_final["date_added"], errors='coerce', format= '%B %d, %Y')
df_union_final
# Out:
#      show_id     type                          title  \
# 0      s2037    Movie                         #Alive
# 1      s2305    Movie  #AnneFrank - Parallel Stories
# 2      s2482    Movie              #FriendButMarried
# 3      s2325    Movie            #FriendButMarried 2
# 4      s5974    Movie                          #Roxy
# ...      ...      ...                            ...
# 8802   s6178  TV Show                       忍者ハットリくん
# 8803   s4915  TV Show                           海的儿子
# 8804   s7102  TV Show                           마녀사냥
# 8805   s5023    Movie                        반드시 잡는다
# 8806   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 0                          Cho Il
# 1     Sabina Fedeli, Anna Migotto
# 2                   Rako Prijanto
# 3                   Rako Prijanto
# 4                 Michael Kennedy
# ...                           ...
# 8802                          NaN
# 8803                          NaN
# 8804                          NaN
# 8805                Hong-seon Kim
# 8806                Young Jun Lee
#
#                                                    cast      country  \
# 0                              Yoo Ah-in, Park Shin-hye  South Korea
# 1                           Helen Mirren, Gengher Gatti        Italy
# 2     Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...    Indonesia
# 3     Adipati Dolken, Mawar de Jongh, Sari Nila, Von...    Indonesia
# 4     Jake Short, Sarah Fisher, Booboo Stewart, Dann...       Canada
# ...                                                 ...          ...
# 8802                                                NaN        Japan
# 8803  Li Nanxing, Christopher Lee, Jesseca Liu, Appl...          NaN
# 8804  Si-kyung Sung, Se-yoon Yoo, Dong-yup Shin, Ji-...  South Korea
# 8805                                      Baek Yoon-sik  South Korea
# 8806  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...          NaN
#
#               date_added  release_year rating   duration  \
# 0      September 8, 2020          2020  TV-MA        NaN
# 1           July 1, 2020          2019  TV-14        NaN
# 2           May 21, 2020          2018   TV-G        NaN
# 3          June 28, 2020          2020   TV-G    104 min
# 4         April 10, 2019          2018  TV-14        NaN
# ...                  ...           ...    ...        ...
# 8802   December 23, 2018          2012  TV-Y7  2 Seasons
# 8803      April 27, 2018          2016  TV-14        NaN
# 8804   February 19, 2018          2015  TV-MA        NaN
# 8805   February 28, 2018          2017  TV-MA    110 min
# 8806   September 1, 2018          2018  TV-Y7     68 min
#
#                                               listed_in  \
# 0        Horror Movies, International Movies, Thrillers
# 1                   Documentaries, International Movies
# 2         Dramas, International Movies, Romantic Movies
# 3         Dramas, International Movies, Romantic Movies
# 4                             Comedies, Romantic Movies
# ...                                                 ...
# 8802                             Anime Series, Kids' TV
# 8803                  International TV Shows, TV Dramas
# 8804  International TV Shows, Korean TV Shows, Stand...
# 8805            Dramas, International Movies, Thrillers
# 8806                           Children & Family Movies
#
#                                             description Genre Premiere  \
# 0     As a grisly virus rampages a city, a lone man ...   NaN      NaN
# 1     Through her diary, Anne Frank's story is retol...   NaN      NaN
# 2     Pining for his high school crush for years, a ...   NaN      NaN
# 3     As Ayu and Ditto finally transition from best ...   NaN      NaN
# 4     A teenage hacker with a huge nose helps a cool...   NaN      NaN
# ...                                                 ...   ...      ...
# 8802  Hailing from the mountains of Iga, Kanzo Hatto...   NaN      NaN
# 8803  Two brothers start a new life in Singapore, wh...   NaN      NaN
# 8804  Four Korean celebrity men and guest stars of b...   NaN      NaN
# 8805  After people in his town start turning up dead...   NaN      NaN
# 8806  Miniforce, a special task force of elite range...   NaN      NaN
#
#       Runtime  IMDB Score Language      fecha
# 0         NaN         NaN      NaN 2020-09-08
# 1         NaN         NaN      NaN 2020-07-01
# 2         NaN         NaN      NaN 2020-05-21
# 3         NaN         NaN      NaN 2020-06-28
# 4         NaN         NaN      NaN 2019-04-10
# ...       ...         ...      ...        ...
# 8802      NaN         NaN      NaN        NaT
# 8803      NaN         NaN      NaN 2018-04-27
# 8804      NaN         NaN      NaN 2018-02-19
# 8805      NaN         NaN      NaN 2018-02-28
# 8806      NaN         NaN      NaN 2018-09-01
#
# [8807 rows x 18 columns]

# %%
df_union_final["duration_clean"] = df_union_final["duration"].str.extract('(\d+)').astype("Int64")
df_union_final[["duration" , "duration_clean"]]
# Out:
#        duration  duration_clean
# 0           NaN            <NA>
# 1           NaN            <NA>
# 2           NaN            <NA>
# 3       104 min             104
# 4           NaN            <NA>
# ...         ...             ...
# 8802  2 Seasons               2
# 8803        NaN            <NA>
# 8804        NaN            <NA>
# 8805    110 min             110
# 8806     68 min              68
#
# [8807 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 2: Normalización de la columna `rating`
#
# La columna `rating` tiene diferentes calificaciones como `PG`, `PG-13`, `R`, entre otras. Debes categorizar estas calificaciones en tres grupos:
#
# - **'General Audience'** para calificaciones como `G`, `PG`.
#
# - **'Teens'** para calificaciones como `PG-13`, `TV-14`.
#
# - **'Adults'** para calificaciones como `R`, `TV-MA`.

# %%
mapa_rating = {"G":"General Audience", "PG":"General Audience" , "PG-13": "Teens", "TV-14": "Teens", "R": "Adults", "TV-MA" : "Adults"}
df_union_final["clasificacion"] = df_union_final["rating"].map(mapa_rating)
df_union_final[["rating", "clasificacion"]]
# Out:
#      rating clasificacion
# 0     TV-MA        Adults
# 1     TV-14         Teens
# 2      TV-G           NaN
# 3      TV-G           NaN
# 4     TV-14         Teens
# ...     ...           ...
# 8802  TV-Y7           NaN
# 8803  TV-14         Teens
# 8804  TV-MA        Adults
# 8805  TV-MA        Adults
# 8806  TV-Y7           NaN
#
# [8807 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 3: Creación de una columna personalizada basada en el elenco
#
# Vamos a identificar si un actor clave como `Leonardo DiCaprio`, `Tom Hanks`, o `Morgan Freeman` aparece en el elenco.
#
# Usa `apply` y una función lambda para crear una nueva columna llamada `has_famous_actor` que contenga `True` si alguno de estos actores está en la lista de `cast` y `False` en caso contrario.

# %%
def actor_bueno(valor_1):
    if valor_1 in ["Leonardo DiCaprio", "Tom Hanks", "Morgan Freeman"] :
        return True
    else:
        return False
    
df_union_final["has_famous_actor"] = df_union_final.apply(lambda x: actor_bueno(x["cast"]),axis=1)
df_union_final.sample(10)
# Out:
#      show_id     type                                  title  \
# 8416   s5106  TV Show                                   Wadi
# 3179   s7009    Movie  Hotel Transylvania 3: Summer Vacation
# 4280   s3547  TV Show                            Luo Bao Bei
# 8726    s323  TV Show                      You're My Destiny
# 2306   s4868  TV Show                            Evil Genius
# 6790   s4736    Movie                 Tere Naal Love Ho Gaya
# 8338    s277  TV Show                                Valeria
# 2780   s6871    Movie                 Golmaal: Fun Unlimited
# 6407    s809    Movie                         Sniper: Legacy
# 6186   s1237    Movie                             Sentinelle
#
#                                  director  \
# 8416                                  NaN
# 3179                   Genndy Tartakovsky
# 4280                                  NaN
# 8726                                  NaN
# 2306  Trey Borzillieri, Barbara Schroeder
# 6790                        Mandeep Kumar
# 8338                        Inma Torrente
# 2780                         Rohit Shetty
# 6407                     Don Michael Paul
# 6186                      Julien Leclercq
#
#                                                    cast  \
# 8416  Syafie Naswip, Ardell Aryana, Naim Daniel, Sha...
# 3179  Adam Sandler, Selena Gomez, Kevin James, Kathr...
# 4280  Hana Burnett, Natalia-Jade Jonathan, Leo Tang,...
# 8726  Joe Chen, Ethan Juan, Baron Chen, Bianca Bai, ...
# 2306                                                NaN
# 6790  Riteish Deshmukh, Genelia D'Souza, Tinnu Anand...
# 8338  Diana Gómez, Silma López, Paula Malia, Teresa ...
# 2780  Ajay Devgn, Tusshar Kapoor, Arshad Warsi, Shar...
# 6407  Tom Berenger, Chad Michael Collins, Doug Allen...
# 6186  Olga Kurylenko, Marilyn Lima, Michel Nabokoff,...
#
#                       country         date_added  release_year rating  \
# 8416                      NaN  December 29, 2017          2015  TV-14
# 3179            United States   January 24, 2019          2018     PG
# 4280    China, United Kingdom    August 31, 2019          2018   TV-Y
# 8726                   Taiwan     August 3, 2021          2008  TV-MA
# 2306            United States       May 11, 2018          2018  TV-MA
# 6790                    India     August 2, 2018          2012  TV-14
# 8338                    Spain    August 13, 2021          2021  TV-MA
# 2780                    India  December 31, 2019          2006  TV-14
# 6407  United States, Bulgaria       June 2, 2021          2014      R
# 6186                   France      March 5, 2021          2021  TV-MA
#
#        duration                                          listed_in  \
# 8416        NaN                  International TV Shows, TV Dramas
# 3179        NaN                 Children & Family Movies, Comedies
# 4280        NaN                         British TV Shows, Kids' TV
# 8726        NaN  International TV Shows, Romantic TV Shows, TV ...
# 2306        NaN           Crime TV Shows, Docuseries, TV Mysteries
# 6790    127 min    Comedies, International Movies, Romantic Movies
# 8338  2 Seasons  International TV Shows, Romantic TV Shows, Spa...
# 2780    148 min                     Comedies, International Movies
# 6407     98 min                                 Action & Adventure
# 6186     81 min   Action & Adventure, Dramas, International Movies
#
#                                             description   Genre  \
# 8416  After the death of his father, a passive and g...     NaN
# 3179  It's love at first sight for Dracula when he m...     NaN
# 4280  A bright and spirited seven-year-old girl uses...     NaN
# 8726  A young woman's romantic cruise ends in a twis...     NaN
# 2306  This baffling true crime story starts with the...     NaN
# 6790  Mini isn't eager to wed the rich suitor who's ...     NaN
# 8338  A writer in creative and marital crises finds ...     NaN
# 2780  Between thwarting crooks and wooing the belle ...     NaN
# 6407  When a troubled sniper begins killing officers...     NaN
# 6186  Transferred home after a traumatizing combat m...  Action
#
#            Premiere  Runtime  IMDB Score Language      fecha  duration_clean  \
# 8416            NaN      NaN         NaN      NaN 2017-12-29            <NA>
# 3179            NaN      NaN         NaN      NaN 2019-01-24            <NA>
# 4280            NaN      NaN         NaN      NaN 2019-08-31            <NA>
# 8726            NaN      NaN         NaN      NaN 2021-08-03            <NA>
# 2306            NaN      NaN         NaN      NaN 2018-05-11            <NA>
# 6790            NaN      NaN         NaN      NaN 2018-08-02             127
# 8338            NaN      NaN         NaN      NaN 2021-08-13               2
# 2780            NaN      NaN         NaN      NaN 2019-12-31             148
# 6407            NaN      NaN         NaN      NaN 2021-06-02              98
# 6186  March 5, 2021     80.0         4.7   French 2021-03-05              81
#
#          clasificacion  has_famous_actor
# 8416             Teens             False
# 3179  General Audience             False
# 4280               NaN             False
# 8726            Adults             False
# 2306            Adults             False
# 6790             Teens             False
# 8338            Adults             False
# 2780             Teens             False
# 6407            Adults             False
# 6186            Adults             False

# %% [markdown]
# #### Ejercicio 4: Creación de una columna personalizada usando lógica condicional
#
# Vamos a crear una columna llamada `is_recent` que identifique si un título fue lanzado en los últimos 5 años.
#
# Crea una función para marcar con `True` si el título es reciente (lanzado en los últimos 5 años) y `False` si no lo es.

# %%
df_union_final["release_year_new"] = pd.to_datetime(df_union_final["release_year"], format='%Y')
df_union_final["is_recent"] = df_union_final["release_year_new"] >= pd.to_datetime('today') - pd.DateOffset(years=5)
df_union_final.sample(10)
# Out:
#      show_id     type                                title  \
# 911    s6281    Movie                      Below Her Mouth
# 1454    s302    Movie                      Chennai Express
# 6880   s8202    Movie              The Bad Education Movie
# 3946   s7259  TV Show                       La Viuda Negra
# 7899   s3731    Movie                      The Wolf's Call
# 2581   s2403    Movie                          From A to B
# 679     s562    Movie          Austin Powers in Goldmember
# 3130    s492    Movie                           Home Again
# 590    s3665  TV Show  Anohana: The Flower We Saw That Day
# 7061   s5211  TV Show               The Day I Met El Chapo
#
#                  director                                               cast  \
# 911          April Mullen  Erika Linder, Natalie Krill, Sebastian Pigott,...
# 1454         Rohit Shetty  Shah Rukh Khan, Deepika Padukone, Nikitin Dhee...
# 6880       Elliot Hegarty  Jack Whitehall, Joanna Scanlan, Iain Glen, Eth...
# 3946     Alejandro Lozano  Ana Serradilla, Julián Román, Ramiro Meneses, ...
# 7899       Antonin Baudry  François Civil, Omar Sy, Mathieu Kassovitz, Re...
# 2581       Ali F. Mostafa  Fahad Albutairi, Shadi Alfons, Fadi Rifaai, Sa...
# 679             Jay Roach  Mike Myers, Beyoncé Knowles-Carter, Seth Green...
# 3130  Hallie Meyers-Shyer  Reese Witherspoon, Michael Sheen, Candice Berg...
# 590                   NaN  Miyu Irino, Ai Kayano, Haruka Tomatsu, Takahir...
# 7061                  NaN                                  Kate del Castillo
#
#                                                 country         date_added  \
# 911                                              Canada     August 1, 2017
# 1454                                              India     August 5, 2021
# 6880                                     United Kingdom  December 15, 2018
# 3946                    Colombia, Mexico, United States   January 15, 2019
# 7899                                             France      June 20, 2019
# 2581  United Arab Emirates, Jordan, Lebanon, Saudi A...      June 11, 2020
# 679                                       United States       July 1, 2021
# 3130                                      United States       July 8, 2021
# 590                                               Japan      July 15, 2019
# 7061                                      United States   October 20, 2017
#
#       release_year rating duration  \
# 911           2016  TV-MA      NaN
# 1454          2013  TV-14  135 min
# 6880          2015  TV-MA      NaN
# 3946          2016  TV-14      NaN
# 7899          2019  TV-14  116 min
# 2581          2014  TV-MA  104 min
# 679           2002  PG-13      NaN
# 3130          2017  PG-13      NaN
# 590           2011  TV-14      NaN
# 7061          2017  TV-MA      NaN
#
#                                               listed_in  \
# 911    Dramas, Independent Movies, International Movies
# 1454  Action & Adventure, Comedies, International Mo...
# 6880                                           Comedies
# 3946  Crime TV Shows, International TV Shows, Spanis...
# 7899            Dramas, International Movies, Thrillers
# 2581             Comedies, Dramas, International Movies
# 679                        Action & Adventure, Comedies
# 3130                  Comedies, Dramas, Romantic Movies
# 590   Anime Series, International TV Shows, Teen TV ...
# 7061  Crime TV Shows, Docuseries, International TV S...
#
#                                             description Genre Premiere  \
# 911   An engaged fashion editor begins a torrid affa...   NaN      NaN
# 1454  What could have been a sad journey turns joyfu...   NaN      NaN
# 6880  Britain's most ineffective but caring teacher ...   NaN      NaN
# 3946  Beautiful and ruthless Griselda Blanco, known ...   NaN      NaN
# 7899  With nuclear war looming, a military expert in...   NaN      NaN
# 2581  To celebrate the memory of their pal who passe...   NaN      NaN
# 679   The world's most shagadelic spy continues his ...   NaN      NaN
# 3130  A newly single mom takes in three young male f...   NaN      NaN
# 590   A teen haunted by the spirit of an old friend ...   NaN      NaN
# 7061  Mexican superstar actress Kate del Castillo re...   NaN      NaN
#
#       Runtime  IMDB Score Language      fecha  duration_clean clasificacion  \
# 911       NaN         NaN      NaN 2017-08-01            <NA>        Adults
# 1454      NaN         NaN      NaN 2021-08-05             135         Teens
# 6880      NaN         NaN      NaN 2018-12-15            <NA>        Adults
# 3946      NaN         NaN      NaN 2019-01-15            <NA>         Teens
# 7899      NaN         NaN      NaN 2019-06-20             116         Teens
# 2581      NaN         NaN      NaN 2020-06-11             104        Adults
# 679       NaN         NaN      NaN 2021-07-01            <NA>         Teens
# 3130      NaN         NaN      NaN 2021-07-08            <NA>         Teens
# 590       NaN         NaN      NaN 2019-07-15            <NA>         Teens
# 7061      NaN         NaN      NaN 2017-10-20            <NA>        Adults
#
#       has_famous_actor release_year_new  is_recent
# 911              False       2016-01-01      False
# 1454             False       2013-01-01      False
# 6880             False       2015-01-01      False
# 3946             False       2016-01-01      False
# 7899             False       2019-01-01      False
# 2581             False       2014-01-01      False
# 679              False       2002-01-01      False
# 3130             False       2017-01-01      False
# 590              False       2011-01-01      False
# 7061             False       2017-01-01      False

# %% [markdown]
# #### Ejercicio 5: Clasificación de películas por década
#
# En este ejercicio, tu objetivo es categorizar los años de lanzamiento de las películas o series en décadas. La columna `release_year` contiene el año de lanzamiento y debes crear una nueva columna llamada `decade` que indique la década correspondiente, como "1990s", "2000s", etc.

# %%
df_union_final["decade"] = (df_union_final["release_year"]// 10*10).astype(str) + "s"
df_union_final.sample(5)
# Out:
#      show_id     type                  title        director  \
# 6594   s8107    Movie             Striptease  Andrew Bergman
# 3335   s3938  TV Show              Imposters             NaN
# 7891   s5442    Movie       The Wishing Tree   Manika Sharma
# 84     s6010    Movie             3 Heroines  Iman Brotoseno
# 3193   s1536  TV Show  How To Ruin Christmas             NaN
#
#                                                    cast        country  \
# 6594  Demi Moore, Burt Reynolds, Armand Assante, Vin...  United States
# 3335  Inbar Lavi, Rob Heaps, Parker Young, Marianne ...  United States
# 7891  Shabana Azmi, Makrand Deshpande, Harshpreet Ka...          India
# 84    Reza Rahadian, Bunga Citra Lestari, Tara Basro...      Indonesia
# 3193                                                NaN   South Africa
#
#              date_added  release_year rating   duration  \
# 6594    January 1, 2021          1996      R    117 min
# 3335      April 5, 2019          2017  TV-MA  2 Seasons
# 7891       June 5, 2017          2017  TV-14    117 min
# 84      January 5, 2019          2016  TV-PG    124 min
# 3193  December 16, 2020          2020  TV-MA        NaN
#
#                                               listed_in  \
# 6594                                   Comedies, Dramas
# 3335  Crime TV Shows, International TV Shows, TV Com...
# 7891  Children & Family Movies, Dramas, Music & Musi...
# 84          Dramas, International Movies, Sports Movies
# 3193     International TV Shows, TV Comedies, TV Dramas
#
#                                             description Genre Premiere  \
# 6594  A former FBI employee works as a stripper to f...   NaN      NaN
# 3335  Supported by a team of fellow thieves, a con a...   NaN      NaN
# 7891  Five children living on the edge of a forest b...   NaN      NaN
# 84    Three Indonesian women break records by becomi...   NaN      NaN
# 3193  Prodigal daughter Tumi tries to make things ri...   NaN      NaN
#
#       Runtime  IMDB Score Language      fecha  duration_clean clasificacion  \
# 6594      NaN         NaN      NaN 2021-01-01             117        Adults
# 3335      NaN         NaN      NaN 2019-04-05               2        Adults
# 7891      NaN         NaN      NaN 2017-06-05             117         Teens
# 84        NaN         NaN      NaN 2019-01-05             124           NaN
# 3193      NaN         NaN      NaN 2020-12-16            <NA>        Adults
#
#       has_famous_actor release_year_new  is_recent decade
# 6594             False       1996-01-01      False  1990s
# 3335             False       2017-01-01      False  2010s
# 7891             False       2017-01-01      False  2010s
# 84               False       2016-01-01      False  2010s
# 3193             False       2020-01-01       True  2020s

# %% [markdown]
# #### Ejercicio 6: Extracción de información
#
# Para practicar la extracción de información:
#
# 1. **Extrae el primer actor** de la lista en la columna `cast` y crea una nueva columna llamada `first_actor`.
#
# 2. **Extrae el primer nombre del director** y guárdalo en una columna llamada `first_name_director`.

# %%
df_union_final["first_actor"] = df_union_final["cast"].str.split(",").str[0]
df_union_final[["cast", "first_actor"]]
# Out:
#                                                    cast     first_actor
# 0                              Yoo Ah-in, Park Shin-hye       Yoo Ah-in
# 1                           Helen Mirren, Gengher Gatti    Helen Mirren
# 2     Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...  Adipati Dolken
# 3     Adipati Dolken, Mawar de Jongh, Sari Nila, Von...  Adipati Dolken
# 4     Jake Short, Sarah Fisher, Booboo Stewart, Dann...      Jake Short
# ...                                                 ...             ...
# 8802                                                NaN             NaN
# 8803  Li Nanxing, Christopher Lee, Jesseca Liu, Appl...      Li Nanxing
# 8804  Si-kyung Sung, Se-yoon Yoo, Dong-yup Shin, Ji-...   Si-kyung Sung
# 8805                                      Baek Yoon-sik   Baek Yoon-sik
# 8806  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...    Um Sang-hyun
#
# [8807 rows x 2 columns]

# %%
df_union_final["first_director"] = df_union_final["director"].str.split(",").str[0]
df_union_final[["director", "first_director"]]
# Out:
#                          director   first_director
# 0                          Cho Il           Cho Il
# 1     Sabina Fedeli, Anna Migotto    Sabina Fedeli
# 2                   Rako Prijanto    Rako Prijanto
# 3                   Rako Prijanto    Rako Prijanto
# 4                 Michael Kennedy  Michael Kennedy
# ...                           ...              ...
# 8802                          NaN              NaN
# 8803                          NaN              NaN
# 8804                          NaN              NaN
# 8805                Hong-seon Kim    Hong-seon Kim
# 8806                Young Jun Lee    Young Jun Lee
#
# [8807 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 7: Limpieza de la columna `cast`
#
# La columna `cast` contiene una lista de actores separados por comas. Tu objetivo es realizar las siguientes tareas:
#
# 1. **Reemplaza los valores nulos** en la columna `cast` por "sin información".
#
# 2. **Contar el número de actores** en cada entrada y crear una nueva columna llamada `num_cast`.
#
# 3. **Normalizar los nombres**: Asegúrate de que los nombres de los actores estén en un formato consistente (por ejemplo, quitar espacios adicionales).

# %%
df_union_final["cast"] = df_union_final["cast"].fillna("sin_informacion")
df_union_final
# Out:
#      show_id     type                          title  \
# 0      s2037    Movie                         #Alive
# 1      s2305    Movie  #AnneFrank - Parallel Stories
# 2      s2482    Movie              #FriendButMarried
# 3      s2325    Movie            #FriendButMarried 2
# 4      s5974    Movie                          #Roxy
# ...      ...      ...                            ...
# 8802   s6178  TV Show                       忍者ハットリくん
# 8803   s4915  TV Show                           海的儿子
# 8804   s7102  TV Show                           마녀사냥
# 8805   s5023    Movie                        반드시 잡는다
# 8806   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 0                          Cho Il
# 1     Sabina Fedeli, Anna Migotto
# 2                   Rako Prijanto
# 3                   Rako Prijanto
# 4                 Michael Kennedy
# ...                           ...
# 8802                          NaN
# 8803                          NaN
# 8804                          NaN
# 8805                Hong-seon Kim
# 8806                Young Jun Lee
#
#                                                    cast      country  \
# 0                              Yoo Ah-in, Park Shin-hye  South Korea
# 1                           Helen Mirren, Gengher Gatti        Italy
# 2     Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...    Indonesia
# 3     Adipati Dolken, Mawar de Jongh, Sari Nila, Von...    Indonesia
# 4     Jake Short, Sarah Fisher, Booboo Stewart, Dann...       Canada
# ...                                                 ...          ...
# 8802                                    sin_informacion        Japan
# 8803  Li Nanxing, Christopher Lee, Jesseca Liu, Appl...          NaN
# 8804  Si-kyung Sung, Se-yoon Yoo, Dong-yup Shin, Ji-...  South Korea
# 8805                                      Baek Yoon-sik  South Korea
# 8806  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...          NaN
#
#               date_added  release_year rating   duration  \
# 0      September 8, 2020          2020  TV-MA        NaN
# 1           July 1, 2020          2019  TV-14        NaN
# 2           May 21, 2020          2018   TV-G        NaN
# 3          June 28, 2020          2020   TV-G    104 min
# 4         April 10, 2019          2018  TV-14        NaN
# ...                  ...           ...    ...        ...
# 8802   December 23, 2018          2012  TV-Y7  2 Seasons
# 8803      April 27, 2018          2016  TV-14        NaN
# 8804   February 19, 2018          2015  TV-MA        NaN
# 8805   February 28, 2018          2017  TV-MA    110 min
# 8806   September 1, 2018          2018  TV-Y7     68 min
#
#                                               listed_in  \
# 0        Horror Movies, International Movies, Thrillers
# 1                   Documentaries, International Movies
# 2         Dramas, International Movies, Romantic Movies
# 3         Dramas, International Movies, Romantic Movies
# 4                             Comedies, Romantic Movies
# ...                                                 ...
# 8802                             Anime Series, Kids' TV
# 8803                  International TV Shows, TV Dramas
# 8804  International TV Shows, Korean TV Shows, Stand...
# 8805            Dramas, International Movies, Thrillers
# 8806                           Children & Family Movies
#
#                                             description Genre Premiere  \
# 0     As a grisly virus rampages a city, a lone man ...   NaN      NaN
# 1     Through her diary, Anne Frank's story is retol...   NaN      NaN
# 2     Pining for his high school crush for years, a ...   NaN      NaN
# 3     As Ayu and Ditto finally transition from best ...   NaN      NaN
# 4     A teenage hacker with a huge nose helps a cool...   NaN      NaN
# ...                                                 ...   ...      ...
# 8802  Hailing from the mountains of Iga, Kanzo Hatto...   NaN      NaN
# 8803  Two brothers start a new life in Singapore, wh...   NaN      NaN
# 8804  Four Korean celebrity men and guest stars of b...   NaN      NaN
# 8805  After people in his town start turning up dead...   NaN      NaN
# 8806  Miniforce, a special task force of elite range...   NaN      NaN
#
#       Runtime  IMDB Score Language      fecha  duration_clean clasificacion  \
# 0         NaN         NaN      NaN 2020-09-08            <NA>        Adults
# 1         NaN         NaN      NaN 2020-07-01            <NA>         Teens
# 2         NaN         NaN      NaN 2020-05-21            <NA>           NaN
# 3         NaN         NaN      NaN 2020-06-28             104           NaN
# 4         NaN         NaN      NaN 2019-04-10            <NA>         Teens
# ...       ...         ...      ...        ...             ...           ...
# 8802      NaN         NaN      NaN        NaT               2           NaN
# 8803      NaN         NaN      NaN 2018-04-27            <NA>         Teens
# 8804      NaN         NaN      NaN 2018-02-19            <NA>        Adults
# 8805      NaN         NaN      NaN 2018-02-28             110        Adults
# 8806      NaN         NaN      NaN 2018-09-01              68           NaN
#
#       has_famous_actor release_year_new  is_recent decade     first_actor  \
# 0                False       2020-01-01       True  2020s       Yoo Ah-in
# 1                False       2019-01-01      False  2010s    Helen Mirren
# 2                False       2018-01-01      False  2010s  Adipati Dolken
# 3                False       2020-01-01       True  2020s  Adipati Dolken
# 4                False       2018-01-01      False  2010s      Jake Short
# ...                ...              ...        ...    ...             ...
# 8802             False       2012-01-01      False  2010s             NaN
# 8803             False       2016-01-01      False  2010s      Li Nanxing
# 8804             False       2015-01-01      False  2010s   Si-kyung Sung
# 8805             False       2017-01-01      False  2010s   Baek Yoon-sik
# 8806             False       2018-01-01      False  2010s    Um Sang-hyun
#
#        first_director
# 0              Cho Il
# 1       Sabina Fedeli
# 2       Rako Prijanto
# 3       Rako Prijanto
# 4     Michael Kennedy
# ...               ...
# 8802              NaN
# 8803              NaN
# 8804              NaN
# 8805    Hong-seon Kim
# 8806    Young Jun Lee
#
# [8807 rows x 26 columns]

# %%
df_union_final["num_cast"] = df_union_final["cast"].apply(lambda x: len(x.split(",")))
df_union_final[["cast", "num_cast"]]
# Out:
#                                                    cast  num_cast
# 0                              Yoo Ah-in, Park Shin-hye         2
# 1                           Helen Mirren, Gengher Gatti         2
# 2     Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...         8
# 3     Adipati Dolken, Mawar de Jongh, Sari Nila, Von...         8
# 4     Jake Short, Sarah Fisher, Booboo Stewart, Dann...         8
# ...                                                 ...       ...
# 8802                                    sin_informacion         1
# 8803  Li Nanxing, Christopher Lee, Jesseca Liu, Appl...         5
# 8804  Si-kyung Sung, Se-yoon Yoo, Dong-yup Shin, Ji-...         5
# 8805                                      Baek Yoon-sik         1
# 8806  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...         6
#
# [8807 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 9: Identificación de Directores Recurrentes
#
# En este ejercicio, debes identificar los directores que aparecen más de una vez en el conjunto de datos. Realiza los siguientes pasos:
#
# 1. **Reemplaza los valores nulos** en la columna `director` por "sin información".
#
# 3. **Cuenta cuántas veces aparece cada director** en la columna creada en el ejercicio 6.
#
# 4. **Filtra aquellos directores que aparecen más de una vez** y crea una nueva columna llamada `recurrent_director` donde se indique "Yes" si el director aparece varias veces o "No" en caso contrario.

# %%
df_union_final["director"] = df_union_final["director"].fillna("sin_informacion")
df_union_final
# Out:
#      show_id     type                          title  \
# 0      s2037    Movie                         #Alive
# 1      s2305    Movie  #AnneFrank - Parallel Stories
# 2      s2482    Movie              #FriendButMarried
# 3      s2325    Movie            #FriendButMarried 2
# 4      s5974    Movie                          #Roxy
# ...      ...      ...                            ...
# 8802   s6178  TV Show                       忍者ハットリくん
# 8803   s4915  TV Show                           海的儿子
# 8804   s7102  TV Show                           마녀사냥
# 8805   s5023    Movie                        반드시 잡는다
# 8806   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 0                          Cho Il
# 1     Sabina Fedeli, Anna Migotto
# 2                   Rako Prijanto
# 3                   Rako Prijanto
# 4                 Michael Kennedy
# ...                           ...
# 8802              sin_informacion
# 8803              sin_informacion
# 8804              sin_informacion
# 8805                Hong-seon Kim
# 8806                Young Jun Lee
#
#                                                    cast      country  \
# 0                              Yoo Ah-in, Park Shin-hye  South Korea
# 1                           Helen Mirren, Gengher Gatti        Italy
# 2     Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...    Indonesia
# 3     Adipati Dolken, Mawar de Jongh, Sari Nila, Von...    Indonesia
# 4     Jake Short, Sarah Fisher, Booboo Stewart, Dann...       Canada
# ...                                                 ...          ...
# 8802                                    sin_informacion        Japan
# 8803  Li Nanxing, Christopher Lee, Jesseca Liu, Appl...          NaN
# 8804  Si-kyung Sung, Se-yoon Yoo, Dong-yup Shin, Ji-...  South Korea
# 8805                                      Baek Yoon-sik  South Korea
# 8806  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...          NaN
#
#               date_added  release_year rating   duration  \
# 0      September 8, 2020          2020  TV-MA        NaN
# 1           July 1, 2020          2019  TV-14        NaN
# 2           May 21, 2020          2018   TV-G        NaN
# 3          June 28, 2020          2020   TV-G    104 min
# 4         April 10, 2019          2018  TV-14        NaN
# ...                  ...           ...    ...        ...
# 8802   December 23, 2018          2012  TV-Y7  2 Seasons
# 8803      April 27, 2018          2016  TV-14        NaN
# 8804   February 19, 2018          2015  TV-MA        NaN
# 8805   February 28, 2018          2017  TV-MA    110 min
# 8806   September 1, 2018          2018  TV-Y7     68 min
#
#                                               listed_in  \
# 0        Horror Movies, International Movies, Thrillers
# 1                   Documentaries, International Movies
# 2         Dramas, International Movies, Romantic Movies
# 3         Dramas, International Movies, Romantic Movies
# 4                             Comedies, Romantic Movies
# ...                                                 ...
# 8802                             Anime Series, Kids' TV
# 8803                  International TV Shows, TV Dramas
# 8804  International TV Shows, Korean TV Shows, Stand...
# 8805            Dramas, International Movies, Thrillers
# 8806                           Children & Family Movies
#
#                                             description Genre Premiere  \
# 0     As a grisly virus rampages a city, a lone man ...   NaN      NaN
# 1     Through her diary, Anne Frank's story is retol...   NaN      NaN
# 2     Pining for his high school crush for years, a ...   NaN      NaN
# 3     As Ayu and Ditto finally transition from best ...   NaN      NaN
# 4     A teenage hacker with a huge nose helps a cool...   NaN      NaN
# ...                                                 ...   ...      ...
# 8802  Hailing from the mountains of Iga, Kanzo Hatto...   NaN      NaN
# 8803  Two brothers start a new life in Singapore, wh...   NaN      NaN
# 8804  Four Korean celebrity men and guest stars of b...   NaN      NaN
# 8805  After people in his town start turning up dead...   NaN      NaN
# 8806  Miniforce, a special task force of elite range...   NaN      NaN
#
#       Runtime  IMDB Score Language      fecha  duration_clean clasificacion  \
# 0         NaN         NaN      NaN 2020-09-08            <NA>        Adults
# 1         NaN         NaN      NaN 2020-07-01            <NA>         Teens
# 2         NaN         NaN      NaN 2020-05-21            <NA>           NaN
# 3         NaN         NaN      NaN 2020-06-28             104           NaN
# 4         NaN         NaN      NaN 2019-04-10            <NA>         Teens
# ...       ...         ...      ...        ...             ...           ...
# 8802      NaN         NaN      NaN        NaT               2           NaN
# 8803      NaN         NaN      NaN 2018-04-27            <NA>         Teens
# 8804      NaN         NaN      NaN 2018-02-19            <NA>        Adults
# 8805      NaN         NaN      NaN 2018-02-28             110        Adults
# 8806      NaN         NaN      NaN 2018-09-01              68           NaN
#
#       has_famous_actor release_year_new  is_recent decade     first_actor  \
# 0                False       2020-01-01       True  2020s       Yoo Ah-in
# 1                False       2019-01-01      False  2010s    Helen Mirren
# 2                False       2018-01-01      False  2010s  Adipati Dolken
# 3                False       2020-01-01       True  2020s  Adipati Dolken
# 4                False       2018-01-01      False  2010s      Jake Short
# ...                ...              ...        ...    ...             ...
# 8802             False       2012-01-01      False  2010s             NaN
# 8803             False       2016-01-01      False  2010s      Li Nanxing
# 8804             False       2015-01-01      False  2010s   Si-kyung Sung
# 8805             False       2017-01-01      False  2010s   Baek Yoon-sik
# 8806             False       2018-01-01      False  2010s    Um Sang-hyun
#
#        first_director  num_cast
# 0              Cho Il         2
# 1       Sabina Fedeli         2
# 2       Rako Prijanto         8
# 3       Rako Prijanto         8
# 4     Michael Kennedy         8
# ...               ...       ...
# 8802              NaN         1
# 8803              NaN         5
# 8804              NaN         5
# 8805    Hong-seon Kim         1
# 8806    Young Jun Lee         6
#
# [8807 rows x 27 columns]

# %%
df_union_final["first_actor"].value_counts().reset_index()
# Out:
#              first_actor  count
# 0         Shah Rukh Khan     26
# 1           Akshay Kumar     23
# 2       Amitabh Bachchan     20
# 3     David Attenborough     20
# 4           Adam Sandler     20
# ...                  ...    ...
# 5395     Warren Christie      1
# 5396      Alberto Ammann      1
# 5397   Balthazar Murillo      1
# 5398        Taiga Nakano      1
# 5399       Baek Yoon-sik      1
#
# [5400 rows x 2 columns]

# %%
def contar_director(valor, lista):
    if lista.count(valor) > 1:
        return "Yes"
    else:
        return "No"

df_union_final["recurrent_director"] = df_union_final["first_director"].apply(lambda x: contar_director(x, df_union_final["first_director"]))
df_union_final
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 7
#       4     else:
#       5         return "No"
# ----> 7 df_union_final["recurrent_director"] = df_union_final["first_director"].apply(lambda x: contar_director(x, df_union_final["first_director"]))
#       8 df_union_final
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[163], line 7, in <lambda>(x)
#       4     else:
#       5         return "No"
# ----> 7 df_union_final["recurrent_director"] = df_union_final["first_director"].apply(lambda x: contar_director(x, df_union_final["first_director"]))
#       8 df_union_final
#
# Cell In[163], line 2, in contar_director(valor, lista)
#       1 def contar_director(valor, lista):
# ----> 2     if lista.count(valor) > 1:
#       3         return "Yes"
#       4     else:
#
# TypeError: count() takes 1 positional argument but 2 were given
